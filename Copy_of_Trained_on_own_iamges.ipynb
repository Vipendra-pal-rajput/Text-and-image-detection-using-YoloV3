# %% [markdown]
# <a href="https://colab.research.google.com/github/Vipendra-pal-rajput/Text-and-image-detection-using-YoloV3/blob/main/Copy_of_Trained_on_own_iamges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Make a Clone of directories and files

# %%
! git clone https://github.com/AntonMu/TrainYourOwnYOLO
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 522 (delta 0), reused 0 (delta 0), pack-reused 519
# Receiving objects: 100% (522/522), 67.52 MiB | 27.07 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %% [markdown]
# **See Directories**

# %%
! dir
# Out:
# sample_data  TrainYourOwnYOLO

# %% [markdown]
# **Change Directories**

# %%
% cd TrainYourOwnYOLO
# Out:
# /content/TrainYourOwnYOLO

# %% [markdown]
# Delete Some folder and files

# %%
# !rm -rf 1_Image_Annotation/Screen_Recordings
# !rm -rf 2_Training/AWS
# !rm -rf Data/Source_Images/Test_Image_Detection_Results
# !mkdir Data/Source_Images/Test_Image_Detection_Results
# !rm -rf Data/Source_Images/Test_Images
# !mkdir Data/Source_Images/Test_Images
# !rm -rf Data/Source_Images/Training_Images/
# !mkdir Data/Source_Images/Training_Images/
# !mkdir Data/Source_Images/Training_Images/vott-csv-export

# %% [markdown]
# **save csv file as 'Annotations-export'.csv
# set patient to 100 in yolotrain.py for continue running**

# %%
# !dir
# Out:
# 1_Image_Annotation  CONTRIBUTING.md  Minimal_Example.py  TrainYourOwnYOLO.ipynb
# 2_Training	    Data	     README.md		 Utils
# 3_Inference	    LICENSE	     requirements.txt

# %%
# !pip -q install wandb
# Out:
#      |████████████████████████████████| 2.0MB 9.4MB/s
#      |████████████████████████████████| 102kB 12.5MB/s
#      |████████████████████████████████| 133kB 52.3MB/s
#      |████████████████████████████████| 163kB 49.1MB/s
#      |████████████████████████████████| 71kB 8.3MB/s
# ...

# %% [markdown]
#  wandb -login passwd b2735b086d9bf1ed53ef962e996afc4b5cbbda42

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
! pip install -U -r requirements.txt
# Out:
# Requirement already up-to-date: absl-py==0.10.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (0.10.0)
# Requirement already up-to-date: appdirs==1.4.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.4.4)
# ...
#      |████████████████████████████████| 215kB 9.1MB/s
# Requirement already up-to-date: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.6.3)
# ...
#      |████████████████████████████████| 1.1MB 15.0MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 163kB 32.9MB/s
# Requirement already up-to-date: chardet==3.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (3.0.4)
# Requirement already up-to-date: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (7.1.2)
# ...

# %%
% cd 1_Image_Annotation
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
! dir
# Out:
# Convert_to_YOLO_format.py  README.md

# %%
# !python Convert_to_YOLO_format.py

# %%
% cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
% cd 2_Training
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
# ...
#
# | |                               #                 | 7568 Elapsed Time: 0:00:03
# Downloaded Raw yolov3.weights in 4.5 seconds
#
# 2021-03-25 06:57:11.507679: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2021-03-25 06:57:12.862145: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-03-25 06:57:12.920422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-25 06:57:12.921026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# ...

# %%
# !dir
# Out:
# Download_and_Convert_YOLO_weights.py  README.md  src  Train_YOLO.py

# %%
# !python Train_YOLO.py
# Out:
# 2021-03-25 06:57:46.748724: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-25 06:57:48.124471: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-03-25 06:57:48.138163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-25 06:57:48.138762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-03-25 06:57:48.138797: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
% cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
% cd 3_Inference
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %%
# !python Detector.py
# Out:
# 2021-03-25 07:41:07.535488: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-25 07:41:09.683303: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-03-25 07:41:09.703268: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-25 07:41:09.703939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-03-25 07:41:09.703982: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !dir
# Out:
# 1_Image_Annotation  CONTRIBUTING.md  Minimal_Example.py  TrainYourOwnYOLO.ipynb
# 2_Training	    Data	     README.md		 Utils
# 3_Inference	    LICENSE	     requirements.txt

# %%
# %cd ..
# Out:
# /content

# %%
# !dir
# Out:
# sample_data  TrainYourOwnYOLO
